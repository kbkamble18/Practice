# %%
marks = [94.4, 87.0, 95.0, 66.0, 45.0]
print(marks)
print(type(marks))
print(marks[0])
print(marks[1])
student=["Karan", 94, "Pune", 92.2]
print(student)
print(student[2])
# Out:
# [94.4, 87.0, 95.0, 66.0, 45.0]
# <class 'list'>
# 94.4
# 87.0
# ['Karan', 94, 'Pune', 92.2]
# Pune

# %%
student_1= ["Madhav", 10]
student_2= ["Vishakha", 12]
print(f'{student_1[0]} is in class {student_1[1]}')
print(f'{student_2[0]} is in class {student_2[1]}')
# Out:
# Madhav is in class 10
# Vishakha is in class 12

# %%
# Class is a blueprint or template
class Student:
    def __init__(self,full_name, class_grade):
        self.name= full_name
        self.grade=class_grade
    def stud_info():
        print("Inside Stude_Info")
    name = "Madhav"
    grade = 10
#Object - Instance of class
student1 = Student("Madhav", 11)
student_info= Student.stud_info
print(student1.name, student1.grade)
student_info()
#student2 = Student()
#print(student2.name, student2.grade)
# Out:
# Madhav 11
# Inside Stude_Info
